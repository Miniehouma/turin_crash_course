# %% [markdown]
# Agreeing to MIT Climate Entrance, the urban warm island impact may be a wonder whereby cities encounter higher discuss temperatures than the encompassing wide open. Researchers allude to zones harrowed by these higher temperatures as urban warm islands, and individuals living in these ranges are especially uncovered to the impacts of climate alter. (https://climate.mit.edu/explainers/urban-heat-islands).
#
# Besides, certain social bunches are especially powerless to emergencies, counting climate alter, for case, **children**, people with inabilities, ethnic minorities, **transient laborers**, **uprooted people**, **more seasoned individuals**, and other socially marginalized bunches. (https://www.worldbank.org/en/topic/social-dimensions-of-climate-change#1).
#
# In case we center our consideration on vagrants (and in specific outcasts) and uprooted individuals, the UNHCR (UN Displaced person Organization) states that the vast majority of displaced people (roughly 78 percent) don't live in camps but in cities, and are hence more powerless to the extraordinary heatwaves caused by climate alter. In common urban areas offer more openings to live independently and discover business, but they too posture major challenges as displaced people are frequently constrained to share convenience or live in non-functional open buildings, collective centers, ghettos or other sorts of casual settlements with substandard living conditions. (https://action.unrefugees.org/refugee-facts/camps/)

# %% [markdown]
# THe UNHCR gives a database with the socioeconomics of **persuasively uprooted populace** counting inside dispaced individuals, outcasts, asylum-seekers and other individuals in require of universal assurance that settled in urban areas within the countries of refuge. Since there's no all inclusive definition of urban, UNCHR classifies an urban area as a settlement with more than 5,000 inhabitants.(2021, 2022 Information: https://www.unhcr.org/refugee-statistics/download/?url=0quh0N)

# %%
Arranges of the cities in Creating nations with urban outcasts settlements were found to at that point recognize:
* Most noteworthy temperatures 2020 - 2023 to recognize temperature varieties slant,
* Days with temperatures >= 35Â° Celsius (that, concurring to WHO, may cause heat-related infections https://www.who.int/news-room/fact-sheets/detail/climate-change-heat-and-health).

Concurring to WHO, newborn children or individuals who are over 60 a long time of age or that have unremitting wellbeing conditions are those most influenced by **heat-related illnesses**, hence the center will be on creating nations facilitating urban coercively uprooted populace where babies < 4 a long time ancient and elderly > 60 a long time ancient are at slightest => 50 (Information sifted through Rotate Table)

# %%
#Test the jupyter software

print("hello world")
# Out:
# hello world

# %%
#import pandas library for data management

import pandas as pd

# %%
#Import the cities CSV file

df=pd.read_csv('Cities.csv')

# %%
#let's test access and show the content of CSV file

df.head()
# Out:
#        Yerevan        Armenia
# 0         Baku     Azerbaijan
# 1  Ouagadougou   Burkina+Faso
# 2    Bujumbura        Burundi
# 3  Brazzaville          Congo
# 4      Abidjan  Cote+d'Ivoire

# %%
#import geopy for geographic data management

from geopy.geocoders import Nominatim

# %%
#Import requests library to access to the api 
#Test the Api and show results

import requests

r=requests.get("https://nominatim.openstreetmap.org/search?q=Tunis,Tunisia&format=json")

# %%
print(r.text)
# Out:
# [{"place_id":45282887,"licence":"Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright","osm_type":"relation","osm_id":8896976,"lat":"36.8002068","lon":"10.1857757","class":"place","type":"city","place_rank":16,"importance":0.6312276453007518,"addresstype":"city","name":"تونس","display_name":"تونس, ولاية تونس, تونس","boundingbox":["36.6925111","36.9430196","10.0037899","10.3548094"]},{"place_id":45416418,"licence":"Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright","osm_type":"relation","osm_id":1435835,"lat":"36.81776455","lon":"10.21268372296034","class":"boundary","type":"administrative","place_rank":8,"importance":0.4682766808779384,"addresstype":"state","name":"ولاية تونس","display_name":"ولاية تونس, تونس","boundingbox":["36.6925111","36.9430196","10.0037899","10.3548094"]},{"place_id":45167805,"licence":"Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright","osm_type":"relation","osm_id":1435828,"lat":"36.7624363","lon":"9.83
# ...

# %%
#importation of the coordinates CSV file

df=pd.read_csv('Cities_coordinates.csv')

# %%
#Test access and show the content of the coordinates file

df.head()
# Out:
#          lat       long                   city   addresstype
# 0  40.177711  44.512623                  Երևան          city
# 1  40.375588  49.832801                   Bakı          city
# 2  12.368187  -1.527094            Ouagadougou          city
# 3  -3.363812  29.367503              Bujumbura          city
# 4  -4.269441  15.271226  Brazzaville (commune)  municipality

# %% [markdown]
# Using the open-meteo.com API, we will show the maximum temperature registred on the last years.

# %%
#Get the maximum temperature from 2021 to 2023

data=requests.get("https://archive-api.open-meteo.com/v1/archive?latitude=9.0358287&longitude=38.7524127&start_date=2021-01-01&end_date=2023-12-31&daily=temperature_2m_max,precipitation_sum")

# %%
#show the result

print(data.text)
# Out:
# {"latitude":9.033392,"longitude":38.771626,"generationtime_ms":24.767041206359863,"utc_offset_seconds":0,"timezone":"GMT","timezone_abbreviation":"GMT","elevation":2472.0,"daily_units":{"time":"iso8601","temperature_2m_max":"°C","precipitation_sum":"mm"},"daily":{"time":["2021-01-01","2021-01-02","2021-01-03","2021-01-04","2021-01-05","2021-01-06","2021-01-07","2021-01-08","2021-01-09","2021-01-10","2021-01-11","2021-01-12","2021-01-13","2021-01-14","2021-01-15","2021-01-16","2021-01-17","2021-01-18","2021-01-19","2021-01-20","2021-01-21","2021-01-22","2021-01-23","2021-01-24","2021-01-25","2021-01-26","2021-01-27","2021-01-28","2021-01-29","2021-01-30","2021-01-31","2021-02-01","2021-02-02","2021-02-03","2021-02-04","2021-02-05","2021-02-06","2021-02-07","2021-02-08","2021-02-09","2021-02-10","2021-02-11","2021-02-12","2021-02-13","2021-02-14","2021-02-15","2021-02-16","2021-02-17","2021-02-18","2021-02-19","2021-02-20","2021-02-21","2021-02-22","2021-02-23","2021-02-24","2021-02-25
# ...
